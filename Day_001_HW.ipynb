# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    MSE = sum((y-yp)**2)/len(y)
    return MSE

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 207.793
# The Mean absolute error is 11.147

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 這次選的資料集為New York City Airbnb Open Data，其中紀錄了2019年紐約地區Airbnb的房源資訊、提供之房客、相關評論...等資料。
#
# 1. 你選的這組資料為何重要
#
# Airbnb身為近幾年興起的新創公司，其營運的一舉一動都備受大家關注，而其自身累積的房源刊登、出租、房客評論等資訊，正是他們一步步改善公司營運模式、營運流程以及提供更好服務的關鍵來源，對於其企業自身的營運及利潤的提昇都十分重要，因此選擇該組資料作為本次研究目標。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 該組資料為Airbnb所提供之開放資料，該來源是Airbnb是一個線上訂房平台，因此所有的房源刊登、租賃關係成立、房客評論...等，都是線上進行，因此所有的資料都可自動地被系統所儲存在資料庫中，以供公司內部做分析使用，而該資料是針對美國紐約地區所擷取的一部分資料。
#
# 3. 蒐集而來的資料型態為何
#
#
#
# 4. 這組資料想解決的問題如何評估
#
# 該組資料提出四大問題，我的角度會從
#
# What can we learn about different hosts and areas?
# What can we learn from predictions? (ex: locations, prices, reviews, etc)
# Which hosts are the busiest and why?
# Is there any noticeable difference of traffic among different areas and what could be the reason for it?
#
#
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 假若我是一個自由載客車隊的經營者，我認為我是在經營一個雙邊平台，同時面對車隊駕駛以及乘客，因此我認為要經營好這樣一個雙邊平台，我認為最重要的是滿足雙邊的需求，對於乘客來說，他們希望可以隨時隨地地叫車，而且不需要等候多時；對於駕駛來說，他們希望可以在營業時間內，載越多客人越好，如何搭起兩邊的需求則是經營該平台的主要難點。因此我認為其核心問題為，如何即時地滿足雙邊需求，若能越即時的滿足雙邊需求，則雙邊對於本平台的服務會越滿意，則更願意持續使用本平台，進而提升客戶黏著度，持續優化客戶服務與體驗。
#
# 彙整上述，整理如下：
# 核心問題：如何即時地滿足駕駛與乘客的需求，在一定時間內，成功地搭起兩者需求
# 我的假設：透過解決核心問題，可提升雙邊顧客滿意度，進而願意持續使用該平台，提升客戶黏著度，並從中賺取利潤
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
#
#
# 3. 蒐集而來的資料型態為何
#
#
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
