# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 100
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import Callback
from sklearn.metrics import confusion_matrix

# Record_fp_tp
class Record_tp_tn(Callback):
    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        record_items = ["val_tp", "val_tn"]
        for i in record_items:
            if i not in self.params['metrics']:
                self.params['metrics'].append(i)
    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        val_tp = sum(y_true*y_pred)
        val_tn = sum((y_true==0) & (y_pred==0))
        
        logs["val_tp"] = val_tp
        logs["val_tn"] = val_tn
        
rec_tptn = Record_tp_tn()

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[rec_tptn]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

valid_tp = model.history.history['val_tn']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 6s 112us/step - loss: 2.2552 - accuracy: 0.2683 - val_loss: 2.1551 - val_accuracy: 0.1792
# Epoch 2/100
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.7580 - accuracy: 0.3931 - val_loss: 1.9610 - val_accuracy: 0.3285
# Epoch 3/100
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.6316 - accuracy: 0.4352 - val_loss: 1.7996 - val_accuracy: 0.3839
# Epoch 4/100
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.5579 - accuracy: 0.4584 - val_loss: 1.7068 - val_accuracy: 0.4102
# Epoch 5/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.5012 - accuracy: 0.4794 - val_loss: 1.6290 - val_accuracy: 0.4329
# Epoch 6/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.4550 - accuracy: 0.4944 - val_loss: 1.5803 - val_accuracy: 0.4460
# Epoch 7/100
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.4138 - accuracy: 0.5087 - val_loss: 1.5512 - val_accuracy: 0.4548
# Epoch 8/100
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.3778 - accuracy: 0.5218 - val_loss: 1.5224 - val_accuracy: 0.4645
# Epoch 9/100
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.3474 - accuracy: 0.5325 - val_loss: 1.5122 - val_accuracy: 0.4630
# Epoch 10/100
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.3157 - accuracy: 0.5435 - val_loss: 1.5014 - val_accuracy: 0.4721
# Epoch 11/100
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.2884 - accuracy: 0.5544 - val_loss: 1.4792 - val_accuracy: 0.4759
# Epoch 12/100
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.2613 - accuracy: 0.5627 - val_loss: 1.4852 - val_accuracy: 0.4722
# Epoch 13/100
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.2345 - accuracy: 0.5727 - val_loss: 1.4729 - val_accuracy: 0.4791
# Epoch 14/100
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.2098 - accuracy: 0.5834 - val_loss: 1.4652 - val_accuracy: 0.4837
# Epoch 15/100
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.1867 - accuracy: 0.5909 - val_loss: 1.4830 - val_accuracy: 0.4808
# Epoch 16/100
# 50000/50000 [==============================] - 5s 98us/step - loss: 1.1627 - accuracy: 0.5988 - val_loss: 1.4674 - val_accuracy: 0.4806
# Epoch 17/100
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.1391 - accuracy: 0.6096 - val_loss: 1.4600 - val_accuracy: 0.4872
# Epoch 18/100
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.1170 - accuracy: 0.6175 - val_loss: 1.4662 - val_accuracy: 0.4844
# Epoch 19/100
# 50000/50000 [==============================] - 5s 98us/step - loss: 1.0972 - accuracy: 0.6250 - val_loss: 1.4647 - val_accuracy: 0.4829
# Epoch 20/100
# 50000/50000 [==============================] - 6s 111us/step - loss: 1.0728 - accuracy: 0.6339 - val_loss: 1.4602 - val_accuracy: 0.4831
# Epoch 21/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.0507 - accuracy: 0.6431 - val_loss: 1.4598 - val_accuracy: 0.4892
# Epoch 22/100
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.0302 - accuracy: 0.6501 - val_loss: 1.4667 - val_accuracy: 0.4889
# Epoch 23/100
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.0098 - accuracy: 0.6589 - val_loss: 1.4670 - val_accuracy: 0.4938
# Epoch 24/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.9887 - accuracy: 0.6651 - val_loss: 1.4663 - val_accuracy: 0.4906
# Epoch 25/100
# 50000/50000 [==============================] - 5s 93us/step - loss: 0.9692 - accuracy: 0.6718 - val_loss: 1.4638 - val_accuracy: 0.4923
# Epoch 26/100
# 50000/50000 [==============================] - 5s 96us/step - loss: 0.9460 - accuracy: 0.6823 - val_loss: 1.4673 - val_accuracy: 0.4907
# Epoch 27/100
# 50000/50000 [==============================] - 5s 96us/step - loss: 0.9260 - accuracy: 0.6880 - val_loss: 1.4640 - val_accuracy: 0.4946
# Epoch 28/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.9064 - accuracy: 0.6967 - val_loss: 1.4769 - val_accuracy: 0.4879
# Epoch 29/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.8855 - accuracy: 0.7055 - val_loss: 1.4887 - val_accuracy: 0.4866
# Epoch 30/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.8669 - accuracy: 0.7139 - val_loss: 1.4820 - val_accuracy: 0.4947
# Epoch 31/100
# 50000/50000 [==============================] - 5s 97us/step - loss: 0.8446 - accuracy: 0.7230 - val_loss: 1.5031 - val_accuracy: 0.4928
# Epoch 32/100
# 50000/50000 [==============================] - 5s 96us/step - loss: 0.8272 - accuracy: 0.7287 - val_loss: 1.5046 - val_accuracy: 0.4867
# Epoch 33/100
# 50000/50000 [==============================] - 5s 96us/step - loss: 0.8082 - accuracy: 0.7353 - val_loss: 1.5253 - val_accuracy: 0.4907
# Epoch 34/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.7880 - accuracy: 0.7427 - val_loss: 1.5200 - val_accuracy: 0.4910
# Epoch 35/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.7679 - accuracy: 0.7516 - val_loss: 1.5158 - val_accuracy: 0.4938
# Epoch 36/100
# 50000/50000 [==============================] - 5s 97us/step - loss: 0.7529 - accuracy: 0.7571 - val_loss: 1.5315 - val_accuracy: 0.4884
# Epoch 37/100
# 50000/50000 [==============================] - 5s 98us/step - loss: 0.7305 - accuracy: 0.7674 - val_loss: 1.5590 - val_accuracy: 0.4914
# Epoch 38/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.7126 - accuracy: 0.7737 - val_loss: 1.5400 - val_accuracy: 0.4981
# Epoch 39/100
# 50000/50000 [==============================] - 5s 96us/step - loss: 0.6941 - accuracy: 0.7808 - val_loss: 1.5483 - val_accuracy: 0.4944
# Epoch 40/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.6740 - accuracy: 0.7898 - val_loss: 1.5483 - val_accuracy: 0.4959
# Epoch 41/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.6566 - accuracy: 0.7985 - val_loss: 1.5705 - val_accuracy: 0.4915
# Epoch 42/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.6371 - accuracy: 0.8039 - val_loss: 1.5847 - val_accuracy: 0.4934
# Epoch 43/100
# 50000/50000 [==============================] - 5s 93us/step - loss: 0.6190 - accuracy: 0.8120 - val_loss: 1.5888 - val_accuracy: 0.4934
# Epoch 44/100
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.5999 - accuracy: 0.8199 - val_loss: 1.6134 - val_accuracy: 0.4941
# Epoch 45/100
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.5847 - accuracy: 0.8252 - val_loss: 1.6117 - val_accuracy: 0.4925
# Epoch 46/100
# 50000/50000 [==============================] - 5s 101us/step - loss: 0.5679 - accuracy: 0.8319 - val_loss: 1.6445 - val_accuracy: 0.4896
# Epoch 47/100
# 50000/50000 [==============================] - 5s 99us/step - loss: 0.5502 - accuracy: 0.8403 - val_loss: 1.6471 - val_accuracy: 0.4899
# Epoch 48/100
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.5315 - accuracy: 0.8469 - val_loss: 1.6482 - val_accuracy: 0.4916
# Epoch 49/100
# 50000/50000 [==============================] - 5s 100us/step - loss: 0.5153 - accuracy: 0.8527 - val_loss: 1.6624 - val_accuracy: 0.4932
# Epoch 50/100
# 50000/50000 [==============================] - 5s 99us/step - loss: 0.4995 - accuracy: 0.8601 - val_loss: 1.7161 - val_accuracy: 0.4827
# Epoch 51/100
# 50000/50000 [==============================] - 5s 100us/step - loss: 0.4852 - accuracy: 0.8639 - val_loss: 1.7090 - val_accuracy: 0.4860
# Epoch 52/100
# 50000/50000 [==============================] - 5s 97us/step - loss: 0.4668 - accuracy: 0.8718 - val_loss: 1.7237 - val_accuracy: 0.4913
# Epoch 53/100
# 50000/50000 [==============================] - 5s 99us/step - loss: 0.4518 - accuracy: 0.8773 - val_loss: 1.7484 - val_accuracy: 0.4790
# Epoch 54/100
# 50000/50000 [==============================] - 5s 100us/step - loss: 0.4357 - accuracy: 0.8839 - val_loss: 1.7553 - val_accuracy: 0.4847
# Epoch 55/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.4211 - accuracy: 0.8899 - val_loss: 1.7534 - val_accuracy: 0.4849
# Epoch 56/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.4068 - accuracy: 0.8963 - val_loss: 1.7600 - val_accuracy: 0.4892
# Epoch 57/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.3906 - accuracy: 0.9012 - val_loss: 1.7787 - val_accuracy: 0.4890
# Epoch 58/100
# 50000/50000 [==============================] - 5s 97us/step - loss: 0.3762 - accuracy: 0.9087 - val_loss: 1.8129 - val_accuracy: 0.4809
# Epoch 59/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.3622 - accuracy: 0.9144 - val_loss: 1.8503 - val_accuracy: 0.4843
# Epoch 60/100
# 50000/50000 [==============================] - 5s 96us/step - loss: 0.3506 - accuracy: 0.9164 - val_loss: 1.8298 - val_accuracy: 0.4838
# Epoch 61/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.3356 - accuracy: 0.9220 - val_loss: 1.8610 - val_accuracy: 0.4789 -
# Epoch 62/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.3222 - accuracy: 0.9280 - val_loss: 1.8800 - val_accuracy: 0.4815
# Epoch 63/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.3101 - accuracy: 0.9321 - val_loss: 1.9263 - val_accuracy: 0.4786
# Epoch 64/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.2983 - accuracy: 0.9367 - val_loss: 1.9048 - val_accuracy: 0.4867
# Epoch 65/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.2870 - accuracy: 0.9402 - val_loss: 1.9282 - val_accuracy: 0.4838
# Epoch 66/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.2743 - accuracy: 0.9460 - val_loss: 1.9777 - val_accuracy: 0.4797
# Epoch 67/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.2638 - accuracy: 0.9483 - val_loss: 1.9415 - val_accuracy: 0.4837
# Epoch 68/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.2523 - accuracy: 0.9521 - val_loss: 1.9795 - val_accuracy: 0.4793
# Epoch 69/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.2414 - accuracy: 0.9564 - val_loss: 1.9783 - val_accuracy: 0.4841
# Epoch 70/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.2331 - accuracy: 0.9581 - val_loss: 2.0269 - val_accuracy: 0.4782
# Epoch 71/100
# 50000/50000 [==============================] - 5s 97us/step - loss: 0.2225 - accuracy: 0.9624 - val_loss: 2.0849 - val_accuracy: 0.4673
# Epoch 72/100
# 50000/50000 [==============================] - 5s 96us/step - loss: 0.2143 - accuracy: 0.9649 - val_loss: 2.0445 - val_accuracy: 0.4804
# Epoch 73/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.2054 - accuracy: 0.9672 - val_loss: 2.0756 - val_accuracy: 0.4801
# Epoch 74/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.1962 - accuracy: 0.9705 - val_loss: 2.1110 - val_accuracy: 0.4779
# Epoch 75/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.1874 - accuracy: 0.9721 - val_loss: 2.0999 - val_accuracy: 0.4774
# Epoch 76/100
# 50000/50000 [==============================] - 5s 96us/step - loss: 0.1804 - accuracy: 0.9748 - val_loss: 2.0891 - val_accuracy: 0.4845
# Epoch 77/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.1731 - accuracy: 0.9761 - val_loss: 2.1623 - val_accuracy: 0.4734
# Epoch 78/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.1649 - accuracy: 0.9794 - val_loss: 2.1417 - val_accuracy: 0.4800
# Epoch 79/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.1572 - accuracy: 0.9816 - val_loss: 2.1572 - val_accuracy: 0.4800
# Epoch 80/100
# 50000/50000 [==============================] - 5s 97us/step - loss: 0.1509 - accuracy: 0.9827 - val_loss: 2.2047 - val_accuracy: 0.4749
# Epoch 81/100
# 50000/50000 [==============================] - 5s 98us/step - loss: 0.1442 - accuracy: 0.9838 - val_loss: 2.1808 - val_accuracy: 0.4834
# Epoch 82/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.1375 - accuracy: 0.9854 - val_loss: 2.1899 - val_accuracy: 0.4744
# Epoch 83/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.1317 - accuracy: 0.9871 - val_loss: 2.2348 - val_accuracy: 0.4747
# Epoch 84/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.1261 - accuracy: 0.9878 - val_loss: 2.2534 - val_accuracy: 0.4764
# Epoch 85/100
# 50000/50000 [==============================] - 5s 96us/step - loss: 0.1211 - accuracy: 0.9892 - val_loss: 2.2559 - val_accuracy: 0.4773
# Epoch 86/100
# 50000/50000 [==============================] - 5s 101us/step - loss: 0.1162 - accuracy: 0.9897 - val_loss: 2.2832 - val_accuracy: 0.4750
# Epoch 87/100
# 50000/50000 [==============================] - 5s 98us/step - loss: 0.1123 - accuracy: 0.9909 - val_loss: 2.2876 - val_accuracy: 0.4790
# Epoch 88/100
# 50000/50000 [==============================] - 5s 98us/step - loss: 0.1064 - accuracy: 0.9922 - val_loss: 2.3106 - val_accuracy: 0.4759
# Epoch 89/100
# 50000/50000 [==============================] - 5s 101us/step - loss: 0.1014 - accuracy: 0.9928 - val_loss: 2.3258 - val_accuracy: 0.4701
# Epoch 90/100
# 50000/50000 [==============================] - 5s 101us/step - loss: 0.0974 - accuracy: 0.9935 - val_loss: 2.3137 - val_accuracy: 0.4770
# Epoch 91/100
# 50000/50000 [==============================] - 5s 97us/step - loss: 0.0951 - accuracy: 0.9938 - val_loss: 2.3381 - val_accuracy: 0.4745
# Epoch 92/100
# 50000/50000 [==============================] - 5s 96us/step - loss: 0.0906 - accuracy: 0.9946 - val_loss: 2.3514 - val_accuracy: 0.4785
# Epoch 93/100
# 50000/50000 [==============================] - 5s 97us/step - loss: 0.0865 - accuracy: 0.9951 - val_loss: 2.3648 - val_accuracy: 0.4776
# Epoch 94/100
# 50000/50000 [==============================] - 5s 99us/step - loss: 0.0832 - accuracy: 0.9954 - val_loss: 2.4024 - val_accuracy: 0.4703
# Epoch 95/100
# 50000/50000 [==============================] - 5s 109us/step - loss: 0.0794 - accuracy: 0.9962 - val_loss: 2.4008 - val_accuracy: 0.4779
# Epoch 96/100
# 50000/50000 [==============================] - 5s 109us/step - loss: 0.0767 - accuracy: 0.9963 - val_loss: 2.4255 - val_accuracy: 0.4746
# Epoch 97/100
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.0736 - accuracy: 0.9969 - val_loss: 2.4186 - val_accuracy: 0.4756
# Epoch 98/100
# 50000/50000 [==============================] - 5s 108us/step - loss: 0.0719 - accuracy: 0.9969 - val_loss: 2.4584 - val_accuracy: 0.4758
# Epoch 99/100
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.0688 - accuracy: 0.9973 - val_loss: 2.4542 - val_accuracy: 0.4758
# Epoch 100/100
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.0659 - accuracy: 0.9978 - val_loss: 2.4796 - val_accuracy: 0.4763

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()
