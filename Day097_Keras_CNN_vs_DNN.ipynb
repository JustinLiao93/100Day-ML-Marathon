# %%
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop, Adam
import os
# Out:
# Using TensorFlow backend.

# %%
batch_size = 128 # batch 的大小，如果出現 OOM error，請降低這個值
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 10 # 訓練的 epochs 數量

# 讀取資料並檢視
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# 對 label 進行 one-hot encoding (y_trian 原本是純數字)
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## 首先我們使用一般的 DNN (MLP) 來訓練
# 由於 DNN 只能輸入一維的資料，我們要先將影像進行攤平，若 (50000, 32, 32, 3) 的影像，攤平後會變成 (50000, 32*32*3) = (50000, 3072)

# %%
# 將資料攤平成一維資料
x_train = x_train.reshape(50000, 3072) 
x_test = x_test.reshape(10000, 3072)

# 將資料變為 float32 並標準化
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 10s 190us/step - loss: 2.1074 - accuracy: 0.2533 - val_loss: 1.8972 - val_accuracy: 0.3006
# Epoch 2/10
# 50000/50000 [==============================] - 9s 187us/step - loss: 1.8499 - accuracy: 0.3328 - val_loss: 1.7012 - val_accuracy: 0.4080
# Epoch 3/10
# 50000/50000 [==============================] - 10s 192us/step - loss: 1.7789 - accuracy: 0.3598 - val_loss: 1.8004 - val_accuracy: 0.3438
# Epoch 4/10
# 50000/50000 [==============================] - 10s 192us/step - loss: 1.7282 - accuracy: 0.3765 - val_loss: 1.7043 - val_accuracy: 0.3797
# Epoch 5/10
# 50000/50000 [==============================] - 10s 200us/step - loss: 1.6998 - accuracy: 0.3893 - val_loss: 1.7016 - val_accuracy: 0.3911
# Epoch 6/10
# 50000/50000 [==============================] - 10s 196us/step - loss: 1.6739 - accuracy: 0.3973 - val_loss: 1.6198 - val_accuracy: 0.4235
# Epoch 7/10
# 50000/50000 [==============================] - 10s 193us/step - loss: 1.6536 - accuracy: 0.4058 - val_loss: 1.6020 - val_accuracy: 0.4339
# Epoch 8/10
# 50000/50000 [==============================] - 10s 191us/step - loss: 1.6324 - accuracy: 0.4133 - val_loss: 1.5874 - val_accuracy: 0.4429
# Epoch 9/10
# 50000/50000 [==============================] - 9s 189us/step - loss: 1.6165 - accuracy: 0.4219 - val_loss: 1.6058 - val_accuracy: 0.4413
# Epoch 10/10
# 50000/50000 [==============================] - 10s 191us/step - loss: 1.6060 - accuracy: 0.4265 - val_loss: 1.5587 - val_accuracy: 0.4453
# Test loss: 1.5587489097595215
# Test accuracy: 0.44530001282691956

# %% [markdown]
# ## 接下來我們使用 CNN 來訓練神經網路
# CNN 的原理非常適合處理影像類的資料，就讓我們來看看，同樣的訓練條件，CNN 是否顯著優於 DNN 呢?

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_6 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 96s 2ms/step - loss: 1.7435 - accuracy: 0.3690 - val_loss: 1.3159 - val_accuracy: 0.5372
# Epoch 2/10
# 50000/50000 [==============================] - 93s 2ms/step - loss: 1.3057 - accuracy: 0.5383 - val_loss: 1.1442 - val_accuracy: 0.5857
# Epoch 3/10
# 50000/50000 [==============================] - 93s 2ms/step - loss: 1.1004 - accuracy: 0.6138 - val_loss: 0.9968 - val_accuracy: 0.6493
# Epoch 4/10
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.9678 - accuracy: 0.6584 - val_loss: 0.8796 - val_accuracy: 0.6945
# Epoch 5/10
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.8788 - accuracy: 0.6924 - val_loss: 0.7874 - val_accuracy: 0.7232
# Epoch 6/10
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.8058 - accuracy: 0.7205 - val_loss: 0.8132 - val_accuracy: 0.7176
# Epoch 7/10
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.7529 - accuracy: 0.7368 - val_loss: 0.7504 - val_accuracy: 0.7408
# Epoch 8/10
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.7149 - accuracy: 0.7524 - val_loss: 0.7426 - val_accuracy: 0.7513
# Epoch 9/10
# 50000/50000 [==============================] - 98s 2ms/step - loss: 0.6839 - accuracy: 0.7621 - val_loss: 0.7248 - val_accuracy: 0.7591
# Epoch 10/10
# 50000/50000 [==============================] - 108s 2ms/step - loss: 0.6530 - accuracy: 0.7747 - val_loss: 0.7601 - val_accuracy: 0.7351
# Test loss: 0.7601354499816895
# Test accuracy: 0.7350999712944031

# %% [markdown]
# ## 同樣運算 10 個 epochs，但 CNN 在 test data 的準確率顯著優於 DNN!

# %% [markdown]
# ## 作業
# 1. 請試著調整各個超參數，並說明那些超參數對於結果有明顯的影響?
# 2. CNN 與 DNN 哪個模型的參數數量比較多? 造成參數的數量不同的原因在哪?

# %% [markdown]
# ## Answer:
# 1. 更改優化器成效沒有較好，也許可嘗試不同batch size大小，更長epoch、或是不同的網絡結構(隱藏藏層數、神經元數量)來訓練看看
# 2. DNN模型需要更新的模型權重較多(1,841,162 > 1,250,858)，主要是因為CNN模型在convoluation layer後面有些有MaxPooling層，可降低資料維度，相較於CNN模型，上述DNN模型則未導入相對應的降維機制，因此需要更新的模型權重會較多。

# %%
batch_size = 128 # batch 的大小，如果出現 OOM error，請降低這個值
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 10 # 訓練的 epochs 數量

# 讀取資料並檢視
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# 對 label 進行 one-hot encoding (y_trian 原本是純數字)
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# 將資料攤平成一維資料
x_train = x_train.reshape(50000, 3072) 
x_test = x_test.reshape(10000, 3072)

# 將資料變為 float32 並標準化
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

# optimizer改成 Adam
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# 50000 train samples
# 10000 test samples
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 13s 263us/step - loss: 1.9665 - accuracy: 0.2846 - val_loss: 1.7774 - val_accuracy: 0.3732
# Epoch 2/10
# 50000/50000 [==============================] - 13s 260us/step - loss: 1.8170 - accuracy: 0.3397 - val_loss: 1.7096 - val_accuracy: 0.4013
# Epoch 3/10
# 50000/50000 [==============================] - 14s 272us/step - loss: 1.7686 - accuracy: 0.3583 - val_loss: 1.6768 - val_accuracy: 0.4004
# Epoch 4/10
# 50000/50000 [==============================] - 12s 250us/step - loss: 1.7304 - accuracy: 0.3731 - val_loss: 1.6447 - val_accuracy: 0.4199
# Epoch 5/10
# 50000/50000 [==============================] - 12s 246us/step - loss: 1.7048 - accuracy: 0.3847 - val_loss: 1.6236 - val_accuracy: 0.4274
# Epoch 6/10
# 50000/50000 [==============================] - 12s 242us/step - loss: 1.6821 - accuracy: 0.3907 - val_loss: 1.5977 - val_accuracy: 0.4312
# Epoch 7/10
# 50000/50000 [==============================] - 12s 246us/step - loss: 1.6598 - accuracy: 0.3999 - val_loss: 1.5886 - val_accuracy: 0.4354
# Epoch 8/10
# 50000/50000 [==============================] - 13s 255us/step - loss: 1.6483 - accuracy: 0.4053 - val_loss: 1.5673 - val_accuracy: 0.4427
# Epoch 9/10
# 50000/50000 [==============================] - 13s 268us/step - loss: 1.6377 - accuracy: 0.4081 - val_loss: 1.5895 - val_accuracy: 0.4289
# Epoch 10/10
# 50000/50000 [==============================] - 12s 249us/step - loss: 1.6304 - accuracy: 0.4085 - val_loss: 1.5822 - val_accuracy: 0.4435
# Test loss: 1.5822483909606933
# Test accuracy: 0.44350001215934753

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

#optimizer改成 Adam
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_8 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_9 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_10 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_11 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                5130
# _________________________________________________________________
# activation_12 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 122s 2ms/step - loss: 1.6393 - accuracy: 0.3993 - val_loss: 1.2747 - val_accuracy: 0.5415
# Epoch 2/10
# 50000/50000 [==============================] - 122s 2ms/step - loss: 1.2088 - accuracy: 0.5664 - val_loss: 1.0226 - val_accuracy: 0.6427
# Epoch 3/10
# 50000/50000 [==============================] - 126s 3ms/step - loss: 1.0334 - accuracy: 0.6337 - val_loss: 0.9183 - val_accuracy: 0.6843
# Epoch 4/10
# 50000/50000 [==============================] - 120s 2ms/step - loss: 0.9212 - accuracy: 0.6761 - val_loss: 0.8268 - val_accuracy: 0.7124
# Epoch 5/10
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.8393 - accuracy: 0.7064 - val_loss: 0.7782 - val_accuracy: 0.7316
# Epoch 6/10
# 50000/50000 [==============================] - 106s 2ms/step - loss: 0.7747 - accuracy: 0.7271 - val_loss: 0.7528 - val_accuracy: 0.7381
# Epoch 7/10
# 50000/50000 [==============================] - 113s 2ms/step - loss: 0.7271 - accuracy: 0.7446 - val_loss: 0.6948 - val_accuracy: 0.7630
# Epoch 8/10
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.6964 - accuracy: 0.7573 - val_loss: 0.6736 - val_accuracy: 0.7646
# Epoch 9/10
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.6532 - accuracy: 0.7710 - val_loss: 0.6594 - val_accuracy: 0.7728
# Epoch 10/10
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.6254 - accuracy: 0.7808 - val_loss: 0.6763 - val_accuracy: 0.7650
# Test loss: 0.6763134165763856
# Test accuracy: 0.7649999856948853
